# %% [markdown]
# <a href="https://colab.research.google.com/github/TOGAR02/tugas-pemerograman-dasar/blob/main/latihan_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
togar_df = pd.read_csv ("/content/mahasiswa.csv")

# %%
togar_df.head()
# Out:
#      nim   nama           jurusan    umur nilai_akhir  kehadiran_pct  \
# 0  E0001   Aldi            Teknik     150        59.5           82.0
# 1  E0002   Budi            teknik    20.0        84.5           99.0
# 2  E0003  Citra            Energi      -5        56.2           78.0
# 3  E0004   Dewi            Teknik  twenty        63.0           99.0
# 4  E0005    Eka  Manajemen Energi    22.0         999           65.0
#
#   tanggal_daftar
# 0     2024-05-05
# 1     2024-02-14
# 2     2024-04-29
# 3     2024-08-02
# 4     2024-03-22

# %%
togar_df.tail()
# Out:
#       nim   nama           jurusan  umur nilai_akhir  kehadiran_pct  \
# 65  E0066   Oleh            ENERGI  23.0        94.4           98.0
# 66  E0067  Putri            Energi  24.0        59.1           82.0
# 67  E0068   Rafi       Informatika  19.0        84.7           74.0
# 68  E0069  Salsa       Informatika  23.0        63.4           86.0
# 69  E0070  Tasya  Manajemen Energi  23.0        74.5           68.0
#
#    tanggal_daftar
# 65     2024-01-05
# 66     2024-05-15
# 67     2024-05-19
# 68     2024-04-14
# 69     2024-02-17

# %%
togar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70 entries, 0 to 69
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nim             70 non-null     object
#  1   nama            70 non-null     object
#  2   jurusan         70 non-null     object
#  3   umur            70 non-null     object
#  4   nilai_akhir     68 non-null     object
#  5   kehadiran_pct   70 non-null     float64
#  6   tanggal_daftar  68 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 4.4+ KB

# %%
togar_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              0
# nilai_akhir       2
# kehadiran_pct     0
# tanggal_daftar    2
# dtype: int64

# %%
print("jumblah duplikasi: ",togar_df.duplicated().sum())
# Out:
# jumblah duplikasi:  0

# %%
togar_df.drop_duplicates(inplace=True)

# %%
print("jumblah duplikasi: ",togar_df.duplicated().sum())
# Out:
# jumblah duplikasi:  8

# %%
togar_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              0
# nilai_akhir       2
# kehadiran_pct     0
# tanggal_daftar    2
# dtype: int64

# %%
togar_df['jurusan']=togar_df['jurusan'].fillna ("Pembangkit Energi")

# %%
togar_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           2
# umur              0
# nilai_akhir       2
# kehadiran_pct     0
# tanggal_daftar    2
# dtype: int64

# %%
togar_df['umur']= togar_df['umur'].fillna (23)

# %%
togar_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           2
# umur              0
# nilai_akhir       2
# kehadiran_pct     0
# tanggal_daftar    2
# dtype: int64

# %%
togar_df['nilai_akhir']= pd.to_numeric(togar_df['nilai_akhir'],errors='coerce')

# %%
togar_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           2
# umur              2
# nilai_akhir       2
# kehadiran_pct     0
# tanggal_daftar    2
# dtype: int64

# %%
togar_df['nilai_akhir'] = pd.to_numeric(togar_df['nilai_akhir'],errors='coerce')

# %%
togar_df.isna().sum()
togar_df['nilai_akhir'].mean()
# Out:
# np.float64(88.14925373134328)

# %%
togar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nim             78 non-null     object
#  1   nama            78 non-null     object
#  2   jurusan         76 non-null     object
#  3   umur            76 non-null     object
#  4   nilai_akhir     76 non-null     object
#  5   kehadiran_pct   78 non-null     float64
#  6   tanggal_daftar  76 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 4.4+ KB

# %%
togar_df['nilai_akhir'] =togar_df['nilai_akhir'].fillna (88)

# %%
togar_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           2
# umur              2
# nilai_akhir       2
# kehadiran_pct     0
# tanggal_daftar    2
# dtype: int64

# %%
togar_df['kehadiran_pct']= pd.to_numeric(togar_df['kehadiran_pct'],errors='coerce')
togar_df['kehadiran_pct']
# Out:
# 0     82.0
# 1     99.0
# 2     78.0
# 3     99.0
# 4     65.0
#       ...
# 73    76.0
# 74    79.0
# 75    86.0
# 76    66.0
# 77    82.0
# Name: kehadiran_pct, Length: 78, dtype: float64

# %%
togar_df['kehadiran_pct']= togar_df['kehadiran_pct'].fillna (82)

# %%
togar_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           2
# umur              2
# nilai_akhir       2
# kehadiran_pct     0
# tanggal_daftar    2
# dtype: int64

# %%
togar_df
# Out:
#       nim   nama           jurusan    umur  nilai_akhir  kehadiran_pct  \
# 0   E0001   Aldi            Teknik     150         59.5           82.0
# 1   E0002   Budi            teknik    20.0         84.5           99.0
# 2   E0003  Citra            Energi      -5         56.2           78.0
# 3   E0004   Dewi            Teknik  twenty         63.0           99.0
# 4   E0005    Eka  Manajemen Energi    22.0        999.0           65.0
# ..    ...    ...               ...     ...          ...            ...
# 65  E0066   Oleh            ENERGI    23.0         94.4           98.0
# 66  E0067  Putri            Energi    24.0         59.1           82.0
# 67  E0068   Rafi       Informatika    19.0         84.7           74.0
# 68  E0069  Salsa       Informatika    23.0         63.4           86.0
# 69  E0070  Tasya  Manajemen Energi    23.0         74.5           68.0
#
#    tanggal_daftar
# 0      2024-05-05
# 1      2024-02-14
# 2      2024-04-29
# 3      2024-08-02
# ...

# %%
togar_df['tanggal_daftar'] = togar_df['tanggal_daftar'].fillna('2024-03-24')

# %%
togar_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              0
# nilai_akhir       3
# kehadiran_pct     0
# tanggal_daftar    0
# dtype: int64

# %%
togar_df.jurusan.value_counts()
# Out:
# jurusan
# Energi               21
# Informatika          17
# Teknik               12
# Manajemen Energi     11
# Pembangkit Energi     2
# teknik                1
#  energi               1
# ManajemenEnergi       1
# EnErGi                1
# Teknik                1
# ENG                   1
# ENERGI                1
# Name: count, dtype: int64

# %%
togar_df.umur.value_counts()
# Out:
# umur
# 23.0          15
# 25.0          10
# 20.0           9
# 24.0           9
# 22.0           8
# 19.0           7
# 21.0           4
# 23             2
# 150            1
# twenty         1
# -5             1
# 120            1
# NaN_string     1
# 21years        1
# Name: count, dtype: int64

# %%
togar_df['jurusan'] = togar_df['jurusan'].str.lower().str.strip()

# %%
togar_df.jurusan.value_counts()
# Out:
# jurusan
# energi               24
# informatika          17
# teknik               14
# manajemen energi     11
# pembangkit energi     2
# manajemenenergi       1
# eng                   1
# Name: count, dtype: int64

# %%
mapping_jurusan = {
    "energi": "Pembangkit Energi",
    " energi ": "Pembangkit Energi",
    "ENERGI": "Pembangkit Energi",
    "EnErGi": "Pembangkit Energi",
    "eng": "Pembangkit Energi",
    "teknik": "Pembangkit Energi",
    "Teknik ": "Pembangkit Energi",
    "teknik ": "Pembangkit Energi",
    "manajemenenergi": "Manajemen Energi",
    "manajemen energi": "Manajemen Energi"
}

# %%
togar_df["jurusan"] = togar_df["jurusan"].replace(mapping_jurusan)

# %%
togar_df["jurusan"] = togar_df["jurusan"].str.title()

# %%
togar_df.jurusan.value_counts()
# Out:
# jurusan
# Pembangkit Energi    41
# Informatika          17
# Manajemen Energi     12
# Name: count, dtype: int64

# %%
print("Hasil setelah normalisasi dan pemetaan:")
print(togar_df['jurusan'].value_counts())
# Out:
# Hasil setelah normalisasi dan pemetaan:
# jurusan
# Pembangkit Energi    41
# Informatika          17
# Manajemen Energi     12
# Name: count, dtype: int64

# %%
togar_df.umur.value_counts()
# Out:
# umur
# 23.0          15
# 25.0          10
# 20.0           9
# 24.0           9
# 22.0           8
# 19.0           7
# 21.0           4
# 23             2
# 150            1
# twenty         1
# -5             1
# 120            1
# NaN_string     1
# 21years        1
# Name: count, dtype: int64

# %%
togar_df['umur'] = togar_df['umur'].replace('twenty', 20)

# %%
print(togar_df['umur'].value_counts())
# Out:
# umur
# 23.0          15
# 25.0          10
# 20.0           9
# 24.0           9
# 22.0           8
# 19.0           7
# 21.0           4
# 23             2
# 150            1
# 20             1
# -5             1
# 120            1
# NaN_string     1
# 21years        1
# Name: count, dtype: int64

# %%
"""mapping_umur = {
    'twenty': 20,
    '21years': 21,
    'NaN_string': np.nan,
    -5: np.nan,
    120: np.nan,
    150: np.nan
}
"""
# Out:
# "mapping_umur = {\n    'twenty': 20,\n    '21years': 21,\n    'NaN_string': np.nan,\n    -5: np.nan,\n    120: np.nan,\n    150: np.nan\n}\n"

# %%
togar_df['umur'] = pd.to_numeric(togar_df['umur'], errors='coerce')
togar_df['umur'].mean()
# Out:
# np.float64(25.220588235294116)

# %%
mapping_umur = {
    'twenty': 20,
    '21years': 21,
    'NaN_string': 25,
    -5: 25,
    120: 25,
    150: 25
}

# %%
togar_df['umur'] = togar_df['umur'].replace(mapping_umur)

# %%
print("Hasil setelah pemetaan:")
print(togar_df['umur'].value_counts())
print(f"\nTipe data kolom 'umur' sekarang: {togar_df['umur'].dtype}")
# Out:
# Hasil setelah pemetaan:
# umur
# 23.0    17
# 25.0    13
# 20.0    10
# 24.0     9
# 22.0     8
# 19.0     7
# 21.0     4
# Name: count, dtype: int64
#
# Tipe data kolom 'umur' sekarang: float64

# %%
togar_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              2
# nilai_akhir       3
# kehadiran_pct     0
# tanggal_daftar    0
# dtype: int64

# %%
togar_df.head(50)
# Out:
#       nim    nama            jurusan  umur  nilai_akhir  kehadiran_pct  \
# 0   E0001    Aldi  Pembangkit Energi  25.0         59.5           82.0
# 1   E0002    Budi  Pembangkit Energi  20.0         84.5           99.0
# 2   E0003   Citra  Pembangkit Energi  25.0         56.2           78.0
# 3   E0004    Dewi  Pembangkit Energi  20.0         63.0           99.0
# 4   E0005     Eka   Manajemen Energi  22.0        999.0           65.0
# 5   E0006   Fajar  Pembangkit Energi  21.0        -20.0           78.0
# 6   E0007    Gina        Informatika  19.0         70.2          150.0
# 7   E0008  Hendra  Pembangkit Energi  25.0         56.7          -10.0
# 8   E0009     Ika        Informatika  25.0         58.2           83.0
# 9   E0010    Joko  Pembangkit Energi  23.0         62.7           69.0
# 10  E0011    Kiki  Pembangkit Energi  25.0         66.6           70.0
# 11  E0012    Lina        Informatika  22.0         66.1           82.0
# ...

# %%
togar_df.tail(50)
# Out:
#       nim    nama            jurusan  umur  nilai_akhir  kehadiran_pct  \
# 20  E0021     Uli  Pembangkit Energi  24.0         78.4           90.0
# 21  E0022    Vina  Pembangkit Energi   NaN         75.4           70.0
# 22  E0023   Wawan  Pembangkit Energi  20.0         80.1           92.0
# 23  E0024    Xena        Informatika  22.0         70.3           94.0
# 24  E0025    Yudi  Pembangkit Energi  23.0         89.4           65.0
# 25  E0026    Zara        Informatika  24.0         90.4           82.0
# 26  E0027    Arif  Pembangkit Energi  19.0         66.7           75.0
# 27  E0028    Bima  Pembangkit Energi  24.0         90.0           81.0
# 28  E0029    Cici  Pembangkit Energi  23.0         91.5           84.0
# 29  E0030    Dani  Pembangkit Energi  20.0          NaN           75.0
# 30  E0031    Eros        Informatika  23.0         68.0           66.0
# 31  E0032   Ferry  Pembangkit Energi  25.0         87.3           80.0
# ...

# %%
togar_df['umur'].mean()
# Out:
# np.float64(22.426470588235293)

# %%
togar_df['umur'] = togar_df['umur'].fillna(22)

# %%
togar_df.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              0
# nilai_akhir       3
# kehadiran_pct     0
# tanggal_daftar    0
# dtype: int64

# %%
togar_df.duplicated().sum()

# %%
togar_df.head(55)
# Out:
#       nim    nama            jurusan  umur  nilai_akhir  kehadiran_pct  \
# 0   E0001    Aldi  Pembangkit Energi  25.0         59.5           82.0
# 1   E0002    Budi  Pembangkit Energi  20.0         84.5           99.0
# 2   E0003   Citra  Pembangkit Energi  25.0         56.2           78.0
# 3   E0004    Dewi  Pembangkit Energi  20.0         63.0           99.0
# 4   E0005     Eka   Manajemen Energi  22.0        999.0           65.0
# 5   E0006   Fajar  Pembangkit Energi  21.0        -20.0           78.0
# 6   E0007    Gina        Informatika  19.0         70.2          150.0
# 7   E0008  Hendra  Pembangkit Energi  25.0         56.7          -10.0
# 8   E0009     Ika        Informatika  25.0         58.2           83.0
# 9   E0010    Joko  Pembangkit Energi  23.0         62.7           69.0
# 10  E0011    Kiki  Pembangkit Energi  25.0         66.6           70.0
# 11  E0012    Lina        Informatika  22.0         66.1           82.0
# ...

# %%
togar_df.tail()

# %%
togar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70 entries, 0 to 69
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nim             70 non-null     object
#  1   nama            70 non-null     object
#  2   jurusan         70 non-null     object
#  3   umur            70 non-null     float64
#  4   nilai_akhir     67 non-null     float64
#  5   kehadiran_pct   70 non-null     float64
#  6   tanggal_daftar  70 non-null     object
# dtypes: float64(3), object(4)
# memory usage: 4.4+ KB

# %%
togar_df.to_csv("mahasiswa_clean.csv", index=False)

# %%
from google.colab import files
files.download("mahasiswa_clean.csv")

# %%
togar_df = pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
togar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
togar_df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
togar_df.head(60)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.31     34.19                15.0       5612.0          1283.0
# 1     -114.47     34.40                19.0       7650.0          1901.0
# 2     -114.56     33.69                17.0        720.0           174.0
# 3     -114.57     33.64                14.0       1501.0           337.0
# 4     -114.57     33.57                20.0       1454.0           326.0
# 5     -114.58     33.63                29.0       1387.0           236.0
# 6     -114.58     33.61                25.0       2907.0           680.0
# 7     -114.59     34.83                41.0        812.0           168.0
# 8     -114.59     33.61                34.0       4789.0          1175.0
# 9     -114.60     34.83                46.0       1497.0           309.0
# 10    -114.60     33.62                16.0       3741.0           801.0
# 11    -114.60     33.60                21.0       1988.0           483.0
# ...
