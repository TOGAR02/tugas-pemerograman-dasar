# %% [markdown]
# <a href="https://colab.research.google.com/github/TOGAR02/tugas-pemerograman-dasar/blob/main/latihan_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

city_names = ['Jakarta', 'Bandung', 'Makassar', 'Surabaya', 'Medan', 'Yogyakarta', 'Malang']
population = [498044, 964254, 491918, 8398748, 653115, 883305, 744955]
num_airports = [2, 2, 8, 3, 1, 3, 2]

df = pd.DataFrame({
    'City Name': city_names,
    'Population': population,
    'Airports': num_airports,
})

df
# Out:
#     City Name  Population  Airports
# 0     Jakarta      498044         2
# 1     Bandung      964254         2
# 2    Makassar      491918         8
# 3    Surabaya     8398748         3
# 4       Medan      653115         1
# 5  Yogyakarta      883305         3
# 6      Malang      744955         2

# %%
df.describe()

rata_rata_populasi = df['Population'].mean()
print("Rata-rata populasi:", rata_rata_populasi)

modus_airports = df['Airports'].mode()
print("Modus Airports:", modus_airports)
# Out:
# Rata-rata populasi: 1804905.5714285714
# Modus Airports: 0    2
# Name: Airports, dtype: int64

# %%
import matplotlib.pyplot as plt

df['Population'].hist()
plt.title("Distribusi Populasi Kota")
plt.xlabel("Jumlah Penduduk")
plt.ylabel("Frekuensi")
plt.show()

# %%
corr_matrix = df[['Population', 'Airports']].corr()
print("Korelasi:", corr_matrix)

cov_matrix = df[['Population', 'Airports']].cov()
print("Kovarian:", cov_matrix)
# Out:
# Korelasi:             Population  Airports
# Population    1.000000 -0.026109
# Airports     -0.026109  1.000000
# Kovarian:               Population       Airports
# Population  8.486123e+12 -175648.833333
# Airports   -1.756488e+05       5.333333

# %% [markdown]
# Untuk korelasiinya itu di negatif
#
# Kota dengan penduduk besar tidak cenderung dalam mempunyai banyak bandara

# %%
df['Kategori_Bandara'] = df['Airports'].apply(lambda x: 'Banyak' if x >= 3 else 'Sedikit')
df


group_mean = df.groupby('Kategori_Bandara')['Population'].mean()
print(group_mean)

group_agg = df.groupby('Kategori_Bandara').agg({
    'Population': ['mean', 'max'],
    'Airports': ['mean', 'count']
})
# Out:
# Kategori_Bandara
# Banyak     3.257990e+06
# Sedikit    7.150920e+05
# Name: Population, dtype: float64

# %%
import pandas as pd

body_measurement_df = pd.DataFrame.from_records((
  (2, 83.82, 8.4),
  (4, 99.31, 16.97),
  (3, 96.52, 14.41),
  (6, 114.3, 20.14),
  (4, 101.6, 16.91),
  (2, 86.36, 12.64),
  (3, 92.71, 14.23),
  (2, 85.09, 11.11),
  (2, 85.85, 14.18),
  (5, 106.68, 20.01),
  (4, 99.06, 13.17),
  (5, 109.22, 15.36),
  (4, 100.84, 14.78),
  (6, 115.06, 20.06),
  (2, 84.07, 10.02),
  (7, 121.67, 28.4),
  (3, 94.49, 14.05),
  (6, 116.59, 17.55),
  (7, 121.92, 22.96),
), columns=("age", "height_cm", "weight_kg"))

body_measurement_df
# Out:
#     age  height_cm  weight_kg
# 0     2      83.82       8.40
# 1     4      99.31      16.97
# 2     3      96.52      14.41
# 3     6     114.30      20.14
# 4     4     101.60      16.91
# 5     2      86.36      12.64
# 6     3      92.71      14.23
# 7     2      85.09      11.11
# 8     2      85.85      14.18
# 9     5     106.68      20.01
# 10    4      99.06      13.17
# 11    5     109.22      15.36
# 12    4     100.84      14.78
# 13    6     115.06      20.06
# 14    2      84.07      10.02
# 15    7     121.67      28.40
# 16    3      94.49      14.05
# 17    6     116.59      17.55
# 18    7     121.92      22.96

# %%
body_measurement_df.describe()

mean_height = body_measurement_df['height_cm'].mean()
mean_weight = body_measurement_df['weight_kg'].mean()
print("Rata-rata tinggi:", mean_height)
print("Rata-rata berat:", mean_weight)

mode_age = body_measurement_df['age'].mode()
print("Modus umur:", mode_age)
# Out:
# Rata-rata tinggi: 100.7978947368421
# Rata-rata berat: 16.071052631578947
# Modus umur: 0    2
# Name: age, dtype: int64

# %% [markdown]
# Umur yang sering muncul adalah 2
#
# Untuk berat badan rata rata sedang

# %%
import matplotlib.pyplot as plt

body_measurement_df['height_cm'].hist()
plt.title("Distribusi Tinggi Badan (cm)")
plt.show()

body_measurement_df['weight_kg'].hist()
plt.title("Distribusi Berat Badan (kg)")
plt.show()

# %% [markdown]
# untuk tinggi dan berat badan menyebar rata

# %%
group_mean_age = body_measurement_df.groupby("age").mean()
group_mean_age

group_agg_age = body_measurement_df.groupby("age").agg({
    'height_cm': ['mean', 'min', 'max'],
    'weight_kg': ['mean', 'min', 'max']
})
group_agg_age
# Out:
#       height_cm                 weight_kg
#            mean     min     max      mean    min    max
# age
# 2     85.038000   83.82   86.36   11.2700   8.40  14.18
# 3     94.573333   92.71   96.52   14.2300  14.05  14.41
# 4    100.202500   99.06  101.60   15.4575  13.17  16.97
# 5    107.950000  106.68  109.22   17.6850  15.36  20.01
# 6    115.316667  114.30  116.59   19.2500  17.55  20.14
# 7    121.795000  121.67  121.92   25.6800  22.96  28.40

# %% [markdown]
# Untuk usia dengan rata rata berat paliing tinggi adalah 7 tahun Tinggi akan meningkat sesuai dengan usia, ya

# %%
corr_hw = body_measurement_df[['height_cm', 'weight_kg']].corr()
print(corr_hw)

# Kovarian
cov_hw = body_measurement_df[['height_cm', 'weight_kg']].cov()
print(cov_hw)
# Out:
#            height_cm  weight_kg
# height_cm   1.000000   0.888014
# weight_kg   0.888014   1.000000
#             height_cm  weight_kg
# height_cm  166.583840  54.525886
# weight_kg   54.525886  22.632521

# %% [markdown]
# Untuk korelasinya, kuat
#
# Apakah hubungannya positif? Ya

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
togar_df = pd.read_csv('/content/customers.csv')

# %%
togar_df.head()
# Out:
#    customer_id customer_name             gender  age  \
# 0            1       fulan 1             Female   30
# 1            2       fulan 2  Prefer not to say   69
# 2            3       fulan 3  Prefer not to say   59
# 3            4       fulan 4  Prefer not to say   67
# 4            5       fulan 5  Prefer not to say   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# 4                    Queensland  Australia

# %%
togar_df.tail()
# Out:
#       customer_id customer_name             gender  age  \
# 1002          996     fulan 996  Prefer not to say   59
# 1003          997     fulan 997  Prefer not to say   30
# 1004          998     fulan 998  Prefer not to say   32
# 1005          999     fulan 999  Prefer not to say   30
# 1006         1000    fulan 1000               Male   71
#
#                       home_address  zip_code                city  \
# 1002  0433 Armstrong HillSuite 974      7613     Lake Danielland
# 1003       04 Howell PassSuite 209      6950         Ellaborough
# 1004     72 Annabelle PassApt. 446        52          Kohlerberg
# 1005     170 Wilson AvenueApt. 577      7849      East Oscarfurt
# 1006    1671 Lauren KnollSuite 945      9012  Lake Audreyborough
#
#                   state    country
# 1002           Tasmania  Australia
# 1003           Tasmania  Australia
# 1004         Queensland  Australia
# 1005  Western Australia  Australia
# 1006           Tasmania  Australia

# %%
togar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1007 non-null   int64
#  1   customer_name  1007 non-null   object
#  2   gender         989 non-null    object
#  3   age            1007 non-null   int64
#  4   home_address   1007 non-null   object
#  5   zip_code       1007 non-null   int64
#  6   city           1007 non-null   object
#  7   state          1007 non-null   object
#  8   country        1007 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.9+ KB

# %%
togar_df.isna().sum()
# Out:
# customer_id       0
# customer_name     0
# gender           18
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# dtype: int64

# %%
togar_df['customer_id'] = togar_df['customer_id'].fillna("")


togar_df.isna().sum()
# Out:
# customer_id       0
# customer_name     0
# gender           18
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# dtype: int64

# %%
togar_df['gender'] =togar_df['gender'].fillna (88)

# %%
togar_df.isna().sum()
# Out:
# customer_id      0
# customer_name    0
# gender           0
# age              0
# home_address     0
# zip_code         0
# city             0
# state            0
# country          0
# dtype: int64

# %%
togar_df.duplicated().sum()
# Out:
# np.int64(6)

# %%
togar_df.head(55)
# Out:
#     customer_id customer_name             gender  age  \
# 0             1       fulan 1             Female   30
# 1             2       fulan 2  Prefer not to say   69
# 2             3       fulan 3  Prefer not to say   59
# 3             4       fulan 4  Prefer not to say   67
# 4             5       fulan 5  Prefer not to say   30
# 5             6       fulan 6  Prefer not to say   40
# 6             7       fulan 7  Prefer not to say   76
# 7             8       fulan 8  Prefer not to say   75
# 8             9       fulan 9               Male   51
# 9            10      fulan 10  Prefer not to say   70
# 10           11      fulan 11  Prefer not to say   39
# 11           12      fulan 12  Prefer not to say   78
# 12           13      fulan 13               Male   42
# 13           14      fulan 14  Prefer not to say   36
# 14           15      fulan 15  Prefer not to say   34
# 15           16      fulan 16               Male   75
# 16           17      fulan 17  Prefer not to say   32
# 17           18      fulan 18               Male   79
# 18           19      fulan 19  Prefer not to say   41
# 19           20      fulan 20  Prefer not to say   55
# 20           21      fulan 21  Prefer not to say   31
# 21           22      fulan 22  Prefer not to say   20
# 22           23      fulan 23             Female   32
# 23           24      fulan 24  Prefer not to say   49
# 24           25      fulan 25  Prefer not to say   75
# 25           26      fulan 26  Prefer not to say   50
# 26           27      fulan 27  Prefer not to say   55
# 27           28      fulan 28  Prefer not to say   79
# 28           29      fulan 29               Male   20
# 29           30      fulan 30             Female   38
# 30           31      fulan 31  Prefer not to say   36
# 31           32      fulan 32  Prefer not to say   32
# 32           33      fulan 33               Male   44
# 33           34      fulan 34  Prefer not to say   55
# 34           35      fulan 35               Male   80
# 35           36      fulan 36  Prefer not to say   27
# 36           37      fulan 37               Male   75
# 37           38      fulan 38               Male   34
# 38           39      fulan 39                 88   80
# 39           40      fulan 40  Prefer not to say   59
# 40           41      fulan 41               Male   65
# 41           42      fulan 42  Prefer not to say   37
# 42           43      fulan 43  Prefer not to say   34
# 43           44      fulan 44  Prefer not to say   60
# 44           45      fulan 45               Male   27
# 45           46      fulan 46  Prefer not to say   68
# 46           47      fulan 47  Prefer not to say   54
# 47           48      fulan 48               Male   79
# 48           49      fulan 49             Female   56
# 49           50      fulan 50  Prefer not to say   63
# 50           51      fulan 51  Prefer not to say   52
# 51           52      fulan 52               Male   47
# 52           53      fulan 53               Male   51
# 53           54      fulan 54  Prefer not to say   62
# 54           55      fulan 55  Prefer not to say   45
#
#                          home_address  zip_code                   city  \
# 0      8606 Victoria TerraceSuite 560      5464          Johnstonhaven
# 1          8327 Kirlin SummitApt. 461      8223        New Zacharyfort
# 2           269 Gemma SummitSuite 109      5661               Aliburgh
# 3           743 Bailey GroveSuite 141      1729      South Justinhaven
# 4             48 Hyatt ManorSuite 375      4032         Griffithsshire
# 5     7118 Mccullough SquareSuite 639      9996             Blakehaven
# 6         92 Hills Station StApt. 683       793              Masonfurt
# 7          383 Muller SummitSuite 809      7681                Samside
# 8         57 Greenfelder HillApt. 077         2              Beierport
# 9           615 Hayley KnollSuite 454      2118              Joelburgh
# 10           96 Daniel PlaceSuite 898      7400             Georgeland
# 11             66 Kayla MewsSuite 951      6334            Taylorburgh
# 12              16 Kuhn LoopSuite 442      6170          Maddisonmouth
# 13           403 Doherty RunSuite 497      2050    North Benjaminville
# 14              254 Ali RidgeApt. 350       491             Kiehnburgh
# 15            424 Mason PlaceApt. 181      6438                New Kai
# 16           29 Imogen CrestSuite 275      8309         Lake Graceside
# 17            13 Bailey ManorApt. 848      7171             Walterland
# 18             002 Beau PlazaApt. 308      7053            West Bailey
# 19           2069 Phoebe MallApt. 543      6318            East Audrey
# 20           93 Doherty MewsSuite 649      1133           South Callum
# 21         292 Casper IslandSuite 778      6624                Maxberg
# 22            682 Rose CircleApt. 514      1832              North Mia
# 23        75 Williamson MewsSuite 864      4359            Charliebury
# 24         02 Gabriella PlazaApt. 474      9311            Olivershire
# 25            499 Darcy CrestApt. 192      8816         New Oliverside
# 26         6578 Kayla AvenueSuite 812      3462         Lake Alanafort
# 27           360 Heller DriveApt. 052      5820              West Noah
# 28          52 Kayla CircuitSuite 332      5308     North Matildamouth
# 29        612 Jessica TerraceApt. 847      7110               Jetttown
# 30        471 Bahringer ManorApt. 236       756            Dickensberg
# 31             98 Becker LoopApt. 567      1822       Port Archiemouth
# 32          639 Farrell HillSuite 093      4116             Chaseshire
# 33         09 Robinson SquareApt. 647      5387              Sauerfort
# 34  3168 Bartoletti CrescentSuite 878       593             Port Lucas
# 35           41 Durgan IslandApt. 820      5691             Hamishfurt
# 36       3307 Walsh JunctionSuite 233      9751            Violetville
# 37    2958 Dooley Station StSuite 879      1920             Lake Lilly
# 38    7440 Cameron Estate DrSuite 628      4622  North Victoriachester
# 39        9484 Amelia View RdApt. 760      9767           Port Claudia
# 40      647 Violet Estate DrSuite 364      4320              Port Ella
# 41       778 Wilkinson RidgeSuite 101       268          Gabriellatown
# 42       75 Keeling JunctionSuite 483      1490          South Kaiview
# 43        6308 Amelie MeadowSuite 634      9842               Eliburgh
# 44         3101 Thomson ManorApt. 600      1796                Leofurt
# 45         708 Daniel MeadowSuite 246      5087         Bartolettiside
# 46             59 Wood DriveSuite 806      9780      Lake Nicholasfurt
# 47             78 Nguyen MallApt. 116      4761         Heathcotemouth
# 48              30 Watson WayApt. 179      2511            Port Alyssa
# 49           13 Stokes SummitApt. 125      5725             East Aidan
# 50              59 Hand ManorApt. 544      6322          South Evaport
# 51            012 Cooper MallApt. 259       841           Chelseahaven
# 52      9369 Casper Estate DrApt. 122      9225         Lake Kaylastad
# 53       2912 Adams JunctionSuite 740      5575            West Alyssa
# 54          91 Angelina RidgeApt. 435      9871       Lake Phoenixside
#
#                            state    country
# 0             Northern Territory  Australia
# 1                South Australia  Australia
# 2   Australian Capital Territory  Australia
# 3                     Queensland  Australia
# 4                     Queensland  Australia
# 5                New South Wales  Australia
# 6                     Queensland  Australia
# 7             Northern Territory  Australia
# 8             Northern Territory  Australia
# 9              Western Australia  Australia
# 10            Northern Territory  Australia
# 11               South Australia  Australia
# 12                    Queensland  Australia
# 13               New South Wales  Australia
# 14             Western Australia  Australia
# 15                      Victoria  Australia
# 16  Australian Capital Territory  Australia
# 17               New South Wales  Australia
# 18                      Victoria  Australia
# 19               South Australia  Australia
# 20                      Tasmania  Australia
# 21                      Victoria  Australia
# 22                      Tasmania  Australia
# 23            Northern Territory  Australia
# 24                      Victoria  Australia
# 25               New South Wales  Australia
# 26             Western Australia  Australia
# 27                    Queensland  Australia
# 28                    Queensland  Australia
# 29  Australian Capital Territory  Australia
# 30            Northern Territory  Australia
# 31                    Queensland  Australia
# 32               South Australia  Australia
# 33             Western Australia  Australia
# 34                    Queensland  Australia
# 35                    Queensland  Australia
# 36             Western Australia  Australia
# 37  Australian Capital Territory  Australia
# 38            Northern Territory  Australia
# 39               New South Wales  Australia
# 40               New South Wales  Australia
# 41                      Victoria  Australia
# 42                    Queensland  Australia
# 43                      Tasmania  Australia
# 44  Australian Capital Territory  Australia
# 45  Australian Capital Territory  Australia
# 46             Western Australia  Australia
# 47               New South Wales  Australia
# 48                    Queensland  Australia
# 49             Western Australia  Australia
# 50            Northern Territory  Australia
# 51                      Victoria  Australia
# 52               South Australia  Australia
# 53                    Queensland  Australia
# 54               South Australia  Australia
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['customer_id'].plot(kind='hist', bins=20, title='customer_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['zip_code'].plot(kind='hist', bins=20, title='zip_code')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('state').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='customer_id', y='age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='age', y='zip_code', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['customer_id']
#   ys = series['age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('customer_id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('customer_id')
# _ = plt.ylabel('age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['customer_id']
#   ys = series['age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('customer_id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('state')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='state', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('customer_id')
# _ = plt.ylabel('age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['customer_id']
#   ys = series['zip_code']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('customer_id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('customer_id')
# _ = plt.ylabel('zip_code')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['customer_id']
#   ys = series['zip_code']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('customer_id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('state')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='state', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('customer_id')
# _ = plt.ylabel('zip_code')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['customer_id'].plot(kind='line', figsize=(8, 4), title='customer_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['age'].plot(kind='line', figsize=(8, 4), title='age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['zip_code'].plot(kind='line', figsize=(8, 4), title='zip_code')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['state'].value_counts()
#     for x_label, grp in _df_14.groupby('gender')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('gender')
# _ = plt.ylabel('state')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='customer_id', y='gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_16['state'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_16, x='customer_id', y='state', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='age', y='gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['state'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='age', y='state', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
